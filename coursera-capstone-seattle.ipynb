# %%
# import libraries
# %matplotlib inline
import pandas as pd
import numpy as np
import io
import json
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize

# %%
# download the table
df = pd.read_csv('seattle_neighborhoods.csv')
df.head()
# Out:
#        Neighborhood  Latitude  Longitude
# 0          Belltown   47.6147  -122.3448
# 1         Broadmoor   47.6255  -122.2904
# 2      Capitol Hill   47.6253  -122.3222
# 3  Central District   47.6088  -122.2964
# 4      Denny-Blaine   47.6215  -122.2865

# %%
# get latitude and longitude of Seattle
address = 'Seattle, WA'

geolocator = Nominatim(user_agent="sea_explorer")
location = geolocator.geocode(address)
lat = location.latitude
lng = location.longitude
print('The geograpical coordinates of Seattle are {}, {}.'.format(lat, lng))
# Out:
# The geograpical coordinates of Seattle are 47.6038321, -122.3300624.

# %%
map_seattle = folium.Map(location=[lat, lng], zoom_start=10)

# add markers to map
for lat, lng, Neighborhood in zip(df['Latitude'], df['Longitude'], df['Neighborhood']):
    label = '{}'.format(Neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_seattle)  
    
map_seattle
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# implement foursquare credentials
CLIENT_ID = 'T3TZEZZLU2MUQ12S42VOCX1QAGMJBJJDGRTSY4JYY3JSMNNU' # your Foursquare ID
CLIENT_SECRET = 'LAIPM0VYIGXLD2G4N5VRDG54PQPQSGWJMMUDKT4ICOWNWRBT' # your Foursquare Secret
VERSION = '20191005' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
LIMIT = 100
radius = 500
# Out:
# Your credentails:
# CLIENT_ID: T3TZEZZLU2MUQ12S42VOCX1QAGMJBJJDGRTSY4JYY3JSMNNU
# CLIENT_SECRET:LAIPM0VYIGXLD2G4N5VRDG54PQPQSGWJMMUDKT4ICOWNWRBT

# %%
# create function for exploring Seattle neighborhoods
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# get Seattle venues
seattle_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Belltown
# Broadmoor
# Capitol Hill
# Central District
# Denny-Blaine
# Downtown
# Eastlake
# First Hill
# International District
# Leschi
# Madison Park
# Madison Valley
# Madrona
# Montlake
# Pioneer Square
# South Lake Union
# Bryant
# Hawthorne Hills
# Lake City
# Laurelhurst
# Maple Leaf
# Matthews Beach
# Northgate
# Ravenna
# Roosevelt
# U-District
# View Ridge
# Wedgwood
# Windermere
# Ballard
# Blue Ridge/North Beach
# Broadview
# Crown Hill
# Fremont
# Green Lake
# Greenwood
# Haller Lake
# Loyal Heights
# Magnolia
# Phinney Ridge
# Queen Anne
# Wallingford
# Westlake
# Whittier Heights
# Beacon Hill
# Columbia City
# Georgetown
# Mount Baker
# Rainier Beach
# South Park
# Admiral
# Alki
# Fauntleroy
# Junction

# %%
# get seattle venues info
print(seattle_venues.shape)
seattle_venues.head()
seattle_venues.groupby('Neighborhood').count()
print('There are {} unique categories.'.format(len(seattle_venues['Venue Category'].unique())))
# Out:
# (1595, 7)
# There are 259 unique categories.

# %%
# one hot encoding
seattle_onehot = pd.get_dummies(seattle_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
seattle_onehot['Neighborhood'] = seattle_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [seattle_onehot.columns[-1]] + list(seattle_onehot.columns[:-1])
seattle_onehot = seattle_onehot[fixed_columns]

seattle_onehot.head()
seattle_onehot.shape
seattle_grouped = seattle_onehot.groupby('Neighborhood').mean().reset_index()
seattle_grouped
seattle_grouped.shape
# Out:
# (54, 259)

# %%
num_top_venues = 5

for hood in seattle_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = seattle_grouped[seattle_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Admiral----
#             venue  freq
# 0     Coffee Shop  0.12
# 1         Theater  0.05
# 2             Pub  0.05
# 3  Ice Cream Shop  0.02
# 4             Spa  0.02
#
#
# ----Alki----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1               Beach  0.06
# 2                Park  0.06
# 3  Italian Restaurant  0.06
# 4         Art Gallery  0.06
#
#
# ----Ballard----
#                venue  freq
# 0               Park  0.14
# 1  Food & Drink Shop  0.14
# 2  French Restaurant  0.14
# 3           Bus Stop  0.14
# 4      Jewelry Store  0.14
#
#
# ----Beacon Hill----
#                 venue  freq
# 0  Light Rail Station  0.33
# 1  Miscellaneous Shop  0.33
# 2         Bus Station  0.33
# 3         Yoga Studio  0.00
# 4              Office  0.00
#
#
# ----Belltown----
#               venue  freq
# 0               Bar  0.07
# 1       Coffee Shop  0.05
# 2  Sushi Restaurant  0.05
# 3      Cocktail Bar  0.04
# 4             Hotel  0.04
#
#
# ----Blue Ridge/North Beach----
#            venue  freq
# 0           Café  0.25
# 1    Bus Station  0.25
# 2           Pool  0.25
# 3  Garden Center  0.25
# 4         Office  0.00
#
#
# ----Broadmoor----
#             venue  freq
# 0  Farmers Market  0.33
# 1     Golf Course  0.33
# 2  Baseball Field  0.33
# 3     Yoga Studio  0.00
# 4            Park  0.00
#
#
# ----Broadview----
#           venue  freq
# 0  Concert Hall   0.4
# 1         Trail   0.2
# 2   Pizza Place   0.2
# 3   Art Gallery   0.2
# 4   Music Venue   0.0
#
#
# ----Bryant----
#                   venue  freq
# 0           Coffee Shop  0.17
# 1           Bus Station  0.08
# 2    Seafood Restaurant  0.08
# 3  Gym / Fitness Center  0.08
# 4    Chinese Restaurant  0.08
#
#
# ----Capitol Hill----
#                 venue  freq
# 0        Cocktail Bar  0.10
# 1                 Bar  0.08
# 2         Coffee Shop  0.08
# 3  Italian Restaurant  0.05
# 4          Restaurant  0.05
#
#
# ----Central District----
#                   venue  freq
# 0  Ethiopian Restaurant  0.36
# 1                Bakery  0.07
# 2                   Bar  0.07
# 3              Gym Pool  0.07
# 4         Grocery Store  0.07
#
#
# ----Columbia City----
#                   venue  freq
# 0           Pizza Place  0.07
# 1        Ice Cream Shop  0.04
# 2  Ethiopian Restaurant  0.04
# 3                  Park  0.04
# 4                   Bar  0.04
#
#
# ----Crown Hill----
#                 venue  freq
# 0  Mexican Restaurant  0.11
# 1           Pet Store  0.11
# 2       Grocery Store  0.11
# 3          Sports Bar  0.11
# 4        Burger Joint  0.11
#
#
# ----Denny-Blaine----
#                  venue  freq
# 0                 Park   0.4
# 1   Country Dance Club   0.2
# 2                Beach   0.2
# 3  Monument / Landmark   0.2
# 4            Irish Pub   0.0
#
#
# ----Downtown----
#                      venue  freq
# 0                    Hotel  0.10
# 1              Coffee Shop  0.07
# 2  New American Restaurant  0.05
# 3       Seafood Restaurant  0.05
# 4             Cocktail Bar  0.04
#
#
# ----Eastlake----
#                 venue  freq
# 0      Sandwich Place  0.12
# 1  Italian Restaurant  0.09
# 2         Coffee Shop  0.09
# 3          Playground  0.06
# 4         Pizza Place  0.06
#
#
# ----Fauntleroy----
#                venue  freq
# 0       Cupcake Shop  0.12
# 1        Coffee Shop  0.12
# 2  Fish & Chips Shop  0.12
# 3               Park  0.12
# 4   Botanical Garden  0.12
#
#
# ----First Hill----
#               venue  freq
# 0    Sandwich Place  0.10
# 1             Hotel  0.08
# 2       Coffee Shop  0.08
# 3  Asian Restaurant  0.04
# 4            Bakery  0.04
#
#
# ----Fremont----
#              venue  freq
# 0      Coffee Shop  0.06
# 1              Bar  0.05
# 2  Thai Restaurant  0.04
# 3              Pub  0.04
# 4     Cocktail Bar  0.02
#
#
# ----Georgetown----
#                     venue  freq
# 0                    Café  0.07
# 1             Coffee Shop  0.07
# 2                     Bar  0.05
# 3                    Park  0.05
# 4  Furniture / Home Store  0.05
#
#
# ----Green Lake----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1  Frozen Yogurt Shop  0.08
# 2                 Spa  0.08
# 3        Burger Joint  0.08
# 4                 Gym  0.08
#
#
# ----Greenwood----
#                 venue  freq
# 0         Coffee Shop  0.12
# 1                 Bar  0.07
# 2  Mexican Restaurant  0.07
# 3         Pizza Place  0.05
# 4                 Spa  0.05
#
#
# ----Haller Lake----
#           venue  freq
# 0  Soccer Field  0.14
# 1  Dance Studio  0.07
# 2   Coffee Shop  0.07
# 3    Food Truck  0.07
# 4   Gas Station  0.07
#
#
# ----Hawthorne Hills----
#                  venue  freq
# 0  American Restaurant  0.29
# 1                 Café  0.14
# 2   Chinese Restaurant  0.14
# 3             Pharmacy  0.14
# 4       Hardware Store  0.14
#
#
# ----International District----
#                    venue  freq
# 0     Chinese Restaurant  0.13
# 1  Vietnamese Restaurant  0.09
# 2                   Café  0.06
# 3                 Bakery  0.06
# 4      Hotpot Restaurant  0.06
#
#
# ----Junction----
#                   venue  freq
# 0           Pizza Place  0.10
# 1           Coffee Shop  0.06
# 2  Gym / Fitness Center  0.04
# 3      Asian Restaurant  0.04
# 4         Design Studio  0.02
#
#
# ----Lake City----
#                 venue  freq
# 0     Thai Restaurant  0.06
# 1  Mexican Restaurant  0.06
# 2                Bank  0.06
# 3    Sushi Restaurant  0.06
# 4         Gas Station  0.03
#
#
# ----Laurelhurst----
#              venue  freq
# 0      Coffee Shop  0.15
# 1       Food Truck  0.08
# 2             Café  0.08
# 3              Gym  0.08
# 4  Thai Restaurant  0.08
#
#
# ----Leschi----
#            venue  freq
# 0    Coffee Shop   0.2
# 1           Park   0.1
# 2      Pet Store   0.1
# 3  Grocery Store   0.1
# 4            Gym   0.1
#
#
# ----Loyal Heights----
#           venue  freq
# 0          Park  0.25
# 1    Food Truck  0.12
# 2    Hobby Shop  0.12
# 3      Bus Stop  0.12
# 4  Soccer Field  0.12
#
#
# ----Madison Park----
#                 venue  freq
# 0                 Bar  0.12
# 1         Flower Shop  0.08
# 2                Park  0.08
# 3                Bank  0.08
# 4  Salon / Barbershop  0.04
#
#
# ----Madison Valley----
#                 venue  freq
# 0  Italian Restaurant  0.09
# 1                Café  0.09
# 2   French Restaurant  0.09
# 3            Bus Stop  0.09
# 4  Spanish Restaurant  0.05
#
#
# ----Madrona----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1         Yoga Studio  0.06
# 2                 Bar  0.06
# 3            Wine Bar  0.06
# 4  Turkish Restaurant  0.06
#
#
# ----Magnolia----
#          venue  freq
# 0         Park  0.08
# 1  Pizza Place  0.08
# 2     Pharmacy  0.08
# 3  Coffee Shop  0.08
# 4         Café  0.04
#
#
# ----Maple Leaf----
#                  venue  freq
# 0          Coffee Shop  0.17
# 1     Toy / Game Store  0.11
# 2  Arts & Crafts Store  0.11
# 3          Video Store  0.11
# 4             Bus Stop  0.06
#
#
# ----Matthews Beach----
#            venue  freq
# 0           Park  0.50
# 1          Trail  0.25
# 2     Playground  0.25
# 3  Movie Theater  0.00
# 4         Museum  0.00
#
#
# ----Montlake----
#             venue  freq
# 0        Bus Stop  0.29
# 1     Coffee Shop  0.14
# 2       Bike Shop  0.07
# 3  History Museum  0.07
# 4            Farm  0.07
#
#
# ----Mount Baker----
#              venue  freq
# 0  Thai Restaurant  0.11
# 1             Park  0.11
# 2      Pizza Place  0.11
# 3      Gas Station  0.05
# 4        Pet Store  0.05
#
#
# ----Northgate----
#             venue  freq
# 0      Shoe Store  0.04
# 1  Sandwich Place  0.04
# 2  Clothing Store  0.04
# 3     Coffee Shop  0.04
# 4  Cosmetics Shop  0.04
#
#
# ----Phinney Ridge----
#                      venue  freq
# 0                      Bar  0.06
# 1  New American Restaurant  0.06
# 2   Thrift / Vintage Store  0.06
# 3             Dessert Shop  0.06
# 4          Thai Restaurant  0.06
#
#
# ----Pioneer Square----
#           venue  freq
# 0   Coffee Shop  0.09
# 1          Café  0.04
# 2  Cocktail Bar  0.04
# 3         Hotel  0.04
# 4    Donut Shop  0.03
#
#
# ----Queen Anne----
#           venue  freq
# 0  Cocktail Bar  0.25
# 1     Pool Hall  0.25
# 2       Brewery  0.25
# 3          Park  0.25
# 4   Music Venue  0.00
#
#
# ----Rainier Beach----
#              venue  freq
# 0           Garden   0.4
# 1   Baseball Field   0.2
# 2     Dessert Shop   0.2
# 3  Vacation Rental   0.2
# 4      Yoga Studio   0.0
#
#
# ----Ravenna----
#                       venue  freq
# 0  Mediterranean Restaurant  0.12
# 1                       Pub  0.06
# 2               Coffee Shop  0.06
# 3          Sushi Restaurant  0.06
# 4                 Bookstore  0.06
#
#
# ----Roosevelt----
#                            venue  freq
# 0                    Coffee Shop  0.15
# 1  Vegetarian / Vegan Restaurant  0.06
# 2             Mexican Restaurant  0.04
# 3                  Grocery Store  0.04
# 4             Salon / Barbershop  0.04
#
#
# ----South Lake Union----
#          venue  freq
# 0  Coffee Shop  0.14
# 1   Food Truck  0.08
# 2         Café  0.06
# 3        Hotel  0.05
# 4          Bar  0.05
#
#
# ----South Park----
#      venue  freq
# 0     Park  0.33
# 1  Brewery  0.33
# 2  Library  0.17
# 3      Bar  0.17
# 4   Office  0.00
#
#
# ----U-District----
#                 venue  freq
# 0     Bubble Tea Shop  0.05
# 1         Coffee Shop  0.04
# 2     Thai Restaurant  0.04
# 3  Chinese Restaurant  0.04
# 4   Indian Restaurant  0.04
#
#
# ----View Ridge----
#            venue  freq
# 0      Racetrack   1.0
# 1    Yoga Studio   0.0
# 2           Park   0.0
# 3  Movie Theater   0.0
# 4         Museum   0.0
#
#
# ----Wallingford----
#              venue  freq
# 0   Ice Cream Shop  0.07
# 1              Bar  0.07
# 2      Coffee Shop  0.07
# 3  Thai Restaurant  0.07
# 4     Noodle House  0.03
#
#
# ----Wedgwood----
#          venue  freq
# 0  Coffee Shop  0.17
# 1   Steakhouse  0.08
# 2  Video Store  0.08
# 3          Pub  0.08
# 4     Pharmacy  0.08
#
#
# ----Westlake----
#              venue  freq
# 0      Coffee Shop  0.11
# 1   Sandwich Place  0.11
# 2         Bus Stop  0.11
# 3  Harbor / Marina  0.11
# 4     Cocktail Bar  0.06
#
#
# ----Whittier Heights----
#            venue  freq
# 0           Park  0.50
# 1  Deli / Bodega  0.25
# 2           Food  0.25
# 3    Yoga Studio  0.00
# 4         Museum  0.00
#
#
# ----Windermere----
#            venue  freq
# 0    Pizza Place   1.0
# 1    Yoga Studio   0.0
# 2           Park   0.0
# 3  Movie Theater   0.0
# 4         Museum   0.0

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 5

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = seattle_grouped['Neighborhood']

for ind in np.arange(seattle_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(seattle_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0      Admiral           Coffee Shop         Grocery Store
# 1         Alki                  Park                 Beach
# 2      Ballard           Coffee Shop            Hobby Shop
# 3  Beacon Hill    Light Rail Station           Bus Station
# 4     Belltown                   Bar           Coffee Shop
#
#   3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue
# 0                   Pub     Gym / Fitness Center           Pizza Place
# 1           Art Gallery       Italian Restaurant           Coffee Shop
# 2     French Restaurant                Gift Shop         Jewelry Store
# 3         Women's Store        Fish & Chips Shop                  Fair
# 4      Sushi Restaurant  New American Restaurant                Bakery

# %%
# set number of clusters
kclusters = 5

seattle_grouped_clustering = seattle_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(seattle_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
seattle_merged = df

# merge seattle_grouped with seattle_data to add latitude/longitude for each neighborhood
seattle_merged = seattle_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

seattle_merged # check the last columns!
# Out:
#               Neighborhood  Latitude  Longitude  Cluster Labels  \
# 0                 Belltown   47.6147  -122.3448               0
# 1                Broadmoor   47.6255  -122.2904               0
# 2             Capitol Hill   47.6253  -122.3222               0
# 3         Central District   47.6088  -122.2964               0
# 4             Denny-Blaine   47.6215  -122.2865               3
# 5                 Downtown   47.6050  -122.3344               0
# 6                 Eastlake   47.6418  -122.3265               0
# 7               First Hill   47.6094  -122.3250               0
# 8   International District   47.5987  -122.3240               0
# 9                   Leschi   47.6003  -122.2928               0
# 10            Madison Park   47.6346  -122.2796               0
# 11          Madison Valley   47.6233  -122.2964               0
# 12                 Madrona   47.6139  -122.2887               0
# 13                Montlake   47.6417  -122.3020               0
# 14          Pioneer Square   47.6015  -122.3343               0
# 15        South Lake Union   47.6256  -122.3344               0
# 16                  Bryant   47.6706  -122.2871               0
# 17         Hawthorne Hills   47.6723  -122.2774               0
# 18               Lake City   47.7193  -122.2953               0
# 19             Laurelhurst   47.6602  -122.2810               0
# 20              Maple Leaf   47.6958  -122.3176               0
# 21          Matthews Beach   47.6959  -122.2762               3
# 22               Northgate   47.7086  -122.3232               0
# 23                 Ravenna   47.6759  -122.3009               0
# 24               Roosevelt   47.6781  -122.3156               0
# 25              U-District   47.6628  -122.3139               0
# 26              View Ridge   47.6844  -122.2738               2
# 27                Wedgwood   47.6901  -122.2905               0
# 28              Windermere   47.6705  -122.2657               1
# 29                 Ballard   47.6792  -122.3860               0
# 30  Blue Ridge/North Beach   47.7015  -122.3754               0
# 31               Broadview   47.7207  -122.3675               0
# 32              Crown Hill   47.6961  -122.3718               0
# 33                 Fremont   47.6542  -122.3500               0
# 34              Green Lake   47.6798  -122.3258               0
# 35               Greenwood   47.6907  -122.3553               0
# 36             Haller Lake   47.7233  -122.3342               0
# 37           Loyal Heights   47.6822  -122.3851               0
# 38                Magnolia   47.6396  -122.3997               0
# 39           Phinney Ridge   47.6761  -122.3542               0
# 40              Queen Anne   47.6323  -122.3569               0
# 41             Wallingford   47.6614  -122.3421               0
# 42                Westlake   47.6322  -122.3416               0
# 43        Whittier Heights   47.6831  -122.3695               3
# 44             Beacon Hill   47.5526  -122.3009               4
# 45           Columbia City   47.5599  -122.2865               0
# 46              Georgetown   47.5475  -122.3215               0
# 47             Mount Baker   47.5784  -122.2930               0
# 48           Rainier Beach   47.5123  -122.2640               0
# 49              South Park   47.5265  -122.3244               3
# 50                 Admiral   47.5812  -122.3866               0
# 51                    Alki   47.5755  -122.4107               0
# 52              Fauntleroy   47.5240  -122.3830               0
# 53                Junction   47.5611  -122.3868               0
#
#        1st Most Common Venue          2nd Most Common Venue  \
# 0                        Bar                    Coffee Shop
# 1          French Restaurant             Italian Restaurant
# 2               Cocktail Bar                    Coffee Shop
# 3       Ethiopian Restaurant                         Bakery
# 4                       Park                          Beach
# 5                      Hotel                    Coffee Shop
# 6             Sandwich Place             Italian Restaurant
# 7             Sandwich Place                    Coffee Shop
# 8         Chinese Restaurant          Vietnamese Restaurant
# 9                 Playground                    Coffee Shop
# 10                       Bar                           Bank
# 11         French Restaurant                       Bus Stop
# 12                 Gift Shop                    Coffee Shop
# 13                  Bus Stop                    Coffee Shop
# 14               Coffee Shop                   Cocktail Bar
# 15               Coffee Shop                     Food Truck
# 16               Coffee Shop             Seafood Restaurant
# 17       American Restaurant                 Hardware Store
# 18               Pizza Place                           Bank
# 19               Coffee Shop                     Food Truck
# 20               Coffee Shop            Arts & Crafts Store
# 21                      Park                          Trail
# 22       Arts & Crafts Store            Sporting Goods Shop
# 23  Mediterranean Restaurant                            Pub
# 24               Coffee Shop  Vegetarian / Vegan Restaurant
# 25           Bubble Tea Shop                    Coffee Shop
# 26                  Mountain                   Tennis Court
# 27               Coffee Shop                           Park
# 28               Pizza Place                  Women's Store
# 29               Coffee Shop                     Hobby Shop
# 30               Bus Station                           Pool
# 31              Concert Hall                          Trail
# 32                Sports Bar                    Coffee Shop
# 33               Coffee Shop                            Bar
# 34               Coffee Shop             Frozen Yogurt Shop
# 35               Coffee Shop                            Bar
# 36              Soccer Field                   Dance Studio
# 37                      Park                    Pizza Place
# 38               Pizza Place                       Pharmacy
# 39               Bus Station                    Pizza Place
# 40                Playground                           Bank
# 41               Coffee Shop                 Ice Cream Shop
# 42           Harbor / Marina                    Coffee Shop
# 43                      Park                  Deli / Bodega
# 44        Light Rail Station                    Bus Station
# 45               Coffee Shop                    Pizza Place
# 46               Coffee Shop                           Café
# 47                      Park                    Pizza Place
# 48                    Garden                 Baseball Field
# 49                      Park                        Brewery
# 50               Coffee Shop                  Grocery Store
# 51                      Park                          Beach
# 52             Deli / Bodega                    Coffee Shop
# 53               Pizza Place                    Coffee Shop
#
#      3rd Most Common Venue    4th Most Common Venue   5th Most Common Venue
# 0         Sushi Restaurant  New American Restaurant                  Bakery
# 1         Sushi Restaurant            Women's Store          Hardware Store
# 2                      Bar               Restaurant      Italian Restaurant
# 3         Asian Restaurant                     Café           Grocery Store
# 4      Monument / Landmark                Surf Spot                    Fair
# 5       Seafood Restaurant  New American Restaurant            Cocktail Bar
# 6              Coffee Shop               Playground                    Park
# 7                    Hotel                   Bakery             Pizza Place
# 8                     Café      Japanese Restaurant                  Bakery
# 9                      Gym                Pet Store           Grocery Store
# 10             Pizza Place              Dry Cleaner       Food & Drink Shop
# 11      Italian Restaurant            Women's Store             Dry Cleaner
# 12          Ice Cream Shop       Turkish Restaurant       French Restaurant
# 13           Grocery Store       Italian Restaurant     American Restaurant
# 14                    Café                    Hotel              Donut Shop
# 15                    Café                    Hotel                     Bar
# 16      Chinese Restaurant        Martial Arts Dojo           Grocery Store
# 17             Dry Cleaner                     Café           Women's Store
# 18      Mexican Restaurant           Gymnastics Gym         Thai Restaurant
# 19               Juice Bar                     Café                    Park
# 20             Video Store         Toy / Game Store       Convenience Store
# 21              Playground            Women's Store                   Field
# 22              Shoe Store           Sandwich Place      Salon / Barbershop
# 23              Bagel Shop              Pizza Place                Creperie
# 24            Burger Joint                      Bar       Indian Restaurant
# 25       Indian Restaurant       Chinese Restaurant         Thai Restaurant
# 26             Fish Market                     Fair      Falafel Restaurant
# 27                     Pub                      Gym                Pharmacy
# 28    Ethiopian Restaurant               Food Truck       Food & Drink Shop
# 29       French Restaurant                Gift Shop           Jewelry Store
# 30           Garden Center                     Café             Art Gallery
# 31             Pizza Place              Art Gallery           Women's Store
# 32            Burger Joint            Grocery Store          Sandwich Place
# 33                     Pub          Thai Restaurant             Music Venue
# 34            Burger Joint                      Spa                     Gym
# 35      Mexican Restaurant              Pizza Place               Bookstore
# 36             Coffee Shop                     Pool             Gas Station
# 37              Hobby Shop             Soccer Field             Coffee Shop
# 38             Coffee Shop       Mexican Restaurant                     Spa
# 39                     Bar          Thai Restaurant  Thrift / Vintage Store
# 40             Pizza Place              Coffee Shop              Distillery
# 41                     Bar          Thai Restaurant            Cupcake Shop
# 42          Sandwich Place            Boat or Ferry    Herbs & Spices Store
# 43                    Food             Dance Studio              Food Truck
# 44           Women's Store        Fish & Chips Shop                    Fair
# 45                     Bar     Ethiopian Restaurant   Vietnamese Restaurant
# 46  Furniture / Home Store                     Park                     Bar
# 47         Thai Restaurant              Coffee Shop                     ATM
# 48         Vacation Rental            Women's Store             Fish Market
# 49                     Bar               Skate Park             Event Space
# 50                     Pub     Gym / Fitness Center             Pizza Place
# 51             Art Gallery       Italian Restaurant             Coffee Shop
# 52       Fish & Chips Shop                     Park          Pilates Studio
# 53     American Restaurant     Gym / Fitness Center        Asian Restaurant

# %%
# create map
map_clusters = folium.Map(location=[lat, lng], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(seattle_merged['Latitude'], seattle_merged['Longitude'], seattle_merged['Neighborhood'], seattle_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
